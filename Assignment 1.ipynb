# %% [markdown]
# ## Assignment 1

# %% [markdown]
# Q1. Write a program that takes two numbers (a = 15 , b = 4) and prints their:
#
#
# - Sum
#
# - Difference
#
# - Product
#
# - Division
#
# - Floor Division
#
# - Modulus

# %%
a = 15

# %%
b = 4

# %%
a+b # Sum
# Out:
# 19

# %%
a-b # Difference
# Out:
# 11

# %%
a*b # Product
# Out:
# 60

# %%
a/b # Division
# Out:
# 3.75

# %%
a//b # Float Division
# Out:
# 3

# %%
a%b # Modulus
# Out:
# 3

# %% [markdown]
# Q2. Write a code to store your favorite food in a variable and print it.

# %%
x = "Mango"

# %%
x
# Out:
# 'Mango'

# %% [markdown]
# Q3. "I have 22 apples and 33 mangoes. How many fruits do I have in total?"
#
# apple = '22'
#
# mangoes = 33

# %%
apple = '22'

# %%
mango = 33

# %%
Fruits = apple+mango # Since in given question, apple quantity is in string form, therefore Operation is not going to perform
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Fruits = apple+mango # Since in given question, apple quantity is in string form, therefore Operation is not going to perform
#
# TypeError: can only concatenate str (not "int") to str

# %%
apple = 22

# %%
Fruit = apple+mango
Fruit # here I have consider apple in integer form, so addition is going to be perform
# Out:
# 55

# %% [markdown]
# Q4. Check the type and convert:
# (num1 = 10, num2 = 5.6, num3 = 4.43, num4='23')
#
# - Integer to float
#
# - Float to integer
#
# - Float to String
#
# - String to Integer

# %%
num1 = 10

# %%
num2 = 5.6

# %%
num3 = 4.43

# %%
num4 = '23'

# %%
float(num1) # integer to float
# Out:
# 10.0

# %%
int(num2)
# Out:
# 5

# %%
str(num3)
# Out:
# '4.43'

# %%
int(num4)
# Out:
# 23

# %% [markdown]
# Q5. Store in a varibale: Write Your name , Your age, Add 1 to your age using a variable, Print final age

# %%
name = 'Shaheer'

# %%
age = 24

# %%
Final_Age = age + 1
Final_Age
# Out:
# 25

# %% [markdown]
# Q6.
#
# a = 2
#
# b = 1
#
# c = 6
#
# d = 3
#
# - Add a and b
#
# - Subtract c and a
#
# - Multiply d and b
#
# - Divide c and d (float division)
#
# - Find modulus of c divided by d
#
# - Square of (d+a)

# %%
a = 2

# %%
b = 1

# %%
c = 6

# %%
d = 3

# %%
a+b # Add a and b
# Out:
# 3

# %%
c-a # Subtract c and a
# Out:
# 4

# %%
d*b # multiply d and b
# Out:
# 3

# %%
c//d # float Division
# Out:
# 2

# %%
c%d
# Out:
# 0

# %%
(d+a)**2
# Out:
# 25

# %% [markdown]
# Q7.
#
# You were 20 years old in the year 2020.
# Now add 5 more years to your age.
# What is your current age now?
#
# Store age in a variable called age. Print final output in same variable

# %%
Age = 20 # in year 2020

# %%
Age = Age + 5
Age
# Out:
# 25

# %% [markdown]
# Q8.
#
# a = '2'
#
# b = '11'
#
# c = 6.3
#
# - Convert a to integer then add to c
#
# - Convert b to float then multiply by c
#
# - Convert c to integer then add to c

# %%
a = '2'

# %%
b = '11'

# %%
c = 6.3

# %%
int(a)+c
# Out:
# 8.3

# %%
float(b)*c
# Out:
# 69.3

# %%
int(c)+c
# Out:
# 12.3

# %% [markdown]
# Q9.
#
# You had 12 books, and you gave 4 to your friend.
# How many books do you have now?
#
# Store books in a variable called books. Print final output in same variable

# %%
books = 12

# %%
books = 12 - 4

# %%
books
# Out:
# 8

# %% [markdown]
# Q10.
#
# You baked 5 cookies. You baked 3 times more cookies today.
# How many cookies did you bake today?
#
# Store cookies in a variable called cookies. Print final output in same variable

# %%
cookies = 5

# %%
cookies = 3 * cookies

# %%
cookies
# Out:
# 15

# %% [markdown]
# Q11.
# Solve the following expression using PEDMAS:
#
# **20 - 4 × (3 + 2) + 18 ÷ 3**

# %%
x = 20 - 4 * (3+2) + 18 /3
x
# Out:
# 6.0
